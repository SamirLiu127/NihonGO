# %% [markdown]
# # Template  of Content Splitting and Path Finding

# %% [markdown]
#     This is the template of our final project content splitting and the shortest path find.
# I have finish the code in the other script but it is not so easy to read so i'm organizing it here.

# %% [markdown]
#     For example, we are using the dat from Hakkaido.
#     My teamate crawl the data from 背包客棧.

# %%
#encoding=utf-8
import jieba
import pandas as pd
import csv
import geocoder
import pandas as pd
import pymysql
import math
import numpy as np

# %% [markdown]
#     this is the userdefined dictionary we make for Hakkaido

# %%
jieba.load_userdict("kanto.txt")

# %% [markdown]
#     and this is the content from 背包客棧.

# %%
df = pd.read_csv('kantocontent.csv')

# %% [markdown]
#     景點辭典存成list 一發便最後做對照以及截取

# %%
tt=[]
with open('kanto.txt',encoding="UTF-8") as f:
    for i in f:
      tt.append(i.strip())

# %% [markdown]
#     將文章中出現的關鍵景點做出截取，做成一個一個tuple，以方便未來做截取
#     然後將每一個set存進一個大list  <-- B

# %%
A=set()
B=[]
for partcontent in df['content']:
    words=jieba.cut(partcontent)
    for word in words:
        for ltt in tt:
            if word == ltt:
                A.add(ltt)
    if len(A)>1:
        B.append(list(A))
    A=set()

# %% [markdown]
#     當初為了做熱度分析，一些比較大的點(如地名、市名、....等等)都有放在關鍵景點詞庫，但是在做路線分析的時候反而會阻礙我們做分析
# 所以我們現在要把大點拿掉。
#     以下這個checkA是日本大點名字的list

# %%
check=open('日本地名大全集.txt',encoding="UTF-8")
checkA=[]
for a in check:
    checkA.append(a.strip())
check.close()

# %% [markdown]
#     下面就來把B做個清理

# %%
flag1=0
afterclean=[]
tmp=[]
for d in B:
    for inn in d:
        for tt in checkA:
            if inn==tt:
                flag1=1
        if flag1==0:
            tmp.append(inn)
        flag1=0
    if len(tmp)>2:
        afterclean.append(tmp)
    tmp=[]

# %%
print(afterclean)
# Out:
# [['銀座', '井之頭公園', '東京', '明治神宮', '淺草寺', '晴空塔', '原宿', '三鷹之森吉卜力美術館'], ['五重塔', '井之頭公園', '東京', '明治神宮', '成田機場', '淺草寺', '晴空塔', '築地市場', '雷門'], ['展望台', '新宿', '富士山', '御殿場'], ['北陸', '輕井澤', '東京', '成田機場'], ['品川水族館', '台場', '東京', '秋葉原', '東京鐵塔', '六本木'], ['淺草神社', '新宿', '東京', '台場', '淺草寺', '富士山', '彩虹大橋', '雷門', '台場海濱公園'], ['北陸', '輕井澤', '東京', '金澤', '東京灣', '東京鐵塔'], ['銀座', '展望台', '新宿', '東京', '台場', '江島神社', '長谷寺', '東京灣', '成田機場', '鎌倉大佛', '神奈川', '築地市場', '江之島', '高德院'], ['赤羽橋', '高田馬場', '成田機場', '六本木之丘', '雷門', '芝公園', '銀座', '東京', '彩虹大橋', '森美術館', '台場', '明治神宮', '秋葉原', '東京鐵塔', '靖國神社', '東京巨蛋', '上野恩賜公園', '富士山', '東京車站', '築地本願寺', '展望台', '晴空塔', '原宿', '築地市場'], ['展望台', '新宿', '東京', '台場', '明治神宮', '東京鐵塔', '東京地鐵', '成田機場', '晴空塔', '富士山', '原宿', '六本木之丘', '忠犬八公像', '六本木'], ['雷門', '東京', '淺草寺', '東京鐵塔'], ['東京', '目黑川', '富士山'], ['千鳥之淵', '東京國立博物館', '皇居', '東京國立近代美術館', '東京都美術館', '井之頭公園', '國立西洋美術館', '增上寺', '東京', '目黑川', '東京鐵塔', '晴空塔', '上野恩賜公園', '淺草寺', '上野公園', '芝公園', '目黑雅敘園', '神保町', '東照宮'], ['東京車站', '東京', '東京迪士尼樂園', '迪士尼樂園', '原宿'], ['輕井澤', '新宿', '東京', '成田機場', '富士山', '茨城'], ['江戶城', '東京', '竹下通', '根津美術館', '原宿'], ['東京車站', '皇居', '東京'], ['皇居', '江戶城', '東京', '東京灣', '富士山', '皇居東御苑', '二重橋'], ['東京天空樹', '展望台', '東京', '埼玉', '晴空塔', '淺草寺', '神奈川'], ['東京', '成田機場', '上野公園'], ['新宿', '東京', '高尾山', '明治神宮外苑'], ['五重塔', '今戶神社', '東京', '竹下通', '日本橋', '淺草寺', '寶藏門', '雷門', '東照宮'], ['北陸', '輕井澤', '新宿', '東京', '富士山', '東京車站'], ['東京', '成田機場', '富士山', '茨城', '輕井澤'], ['淺草觀音寺', '今戶神社', '晴空塔'], ['東京', '神田明神', '國技館', '日本橋', '江戶東京博物館', '淺草寺'], ['江戶城', '東京', '鷲神社', '日本橋', '江戶東京博物館', '富士山'], ['日枝神社', '新宿', '東京', '秋葉原', '水天宮', '晴空塔', '築地市場'], ['展望台', '台場', '東京', '東京鐵塔'], ['東京國立近代美術館', '東京都庭園美術館', '東京', '國立新美術館', '東京車站', '三鷹之森吉卜力美術館', '森美術館'], ['東京', '銀座', '迪士尼樂園'], ['新宿', '台場', '東京', '秋葉原', '東京鐵塔', '江戶東京博物館', '雷門'], ['銀座', '新宿', '東京', '明治神宮', '迪士尼樂園', '東京地鐵', '東京巨蛋', '東京車站'], ['千鳥之淵', '輕井澤', '東京', '秋葉原', '成田機場', '靖國神社'], ['丸之內', '新宿', '東京', '東京車站', '二重橋', '澀谷站'], ['東京', '晴空塔', '淺草寺', '江之島', '雷門'], ['新宿', '東京', '淺草寺', '富士山'], ['東照宮', '華嚴瀑布', '東京', '中禪寺湖'], ['赤羽橋', '新宿', '淺草觀音寺', '成田機場', '上野公園', '六本木之丘', '雷門', '不忍池', '銀座', '墨田水族館', '東京', '森美術館', '東京鐵塔', '富士山', '築地本願寺', '深大寺', '井之頭公園', '鬼太郎茶屋', '水天宮', '晴空塔', '淺草寺'], ['湘南海岸', '東京', '鎌倉高校前站', '東京地鐵', '富士山'], ['新宿', '東京', '成田機場', '淺草寺', '晴空塔', '原宿'], ['草津溫泉', '北輕井澤', '輕井澤'], ['小江戶川越', '東京', '八坂神社', '埼玉'], ['新宿', '東京', '富士山', '富岳風穴'], ['雷門', '東京', '淺草寺', '晴空塔', '墨田水族館'], ['銀座', '東京', '東京地鐵', '淺草寺', '晴空塔', '雷門'], ['築地市場', '東京', '銀座'], ['東京', '六本木', '東京鐵塔'], ['築地市場', '東京', '水天宮', '日本橋', '秋葉原'], ['新宿', '台場', '銀座', '東京'], ['東京', '東京鐵塔', '成田機場', '晴空塔', '築地市場', '芝公園'], ['東京', '銀座', '原宿'], ['赤羽橋', '新宿', '台場', '東京', '秋葉原', '明治神宮', '東京鐵塔', '淺草寺', '晴空塔', '富士山', '築地市場'], ['五重塔', '雷門', '東京', '淺草寺', '寶藏門'], ['築地市場', '台場', '東京', '秋葉原'], ['新宿', '台場', '東京', '明治神宮', '橫濱', '成田機場', '晴空塔', '富士山', '杯麵博物館', '原宿', '築地市場', '雷門', '山下公園'], ['展望台', '東京', '日本橋', '淺草寺', '晴空塔', '雷門'], ['赤羽橋', '東京', '成田機場', '六本木', '東京鐵塔'], ['箱根纜車', '忍野八海', '新宿', '東京', '箱根神社', '長谷寺', '元箱根', '台場', '蘆之湖', '森美術館', '鎌倉大佛', '江之島', '鶴岡八幡宮', '箱根町'], ['輕井澤', '東京', '秋葉原', '晴空塔', '富士山', '原宿'], ['新宿', '東京', '銀座', '台場', '原宿'], ['新宿', '東京巨蛋', '東京', '丸之內'], ['小江戶川越', '東京', '成田機場', '輕井澤'], ['小江戶川越', '東京', '新宿'], ['展望台', '東京', '台場', '晴空塔', '富士山', '雷門'], ['江之島', '雷門', '東京', '上野公園'], ['銀座', '展望台', '東京', '東京地鐵', '東京鐵塔', '晴空塔', '六本木之丘', '六本木'], ['東京', '神樂坂', '鬼子母神', '原宿'], ['成田機場', '東京', '迪士尼樂園'], ['銀座', '忍野八海', '新宿', '東京', '成田機場', '富士山', '御殿場'], ['東京', '鬼太郎茶屋', '善國寺', '神樂坂'], ['龜戶天神社', '丸之內', '東京', '台場', '竹下通', '新宿御苑', '根津神社', '雷門', '晴空塔', '成田機場', '原宿', '東京車站', '不忍池', '澀谷站'], ['銀座', '新宿', '東京', '秋葉原', '成田機場', '富士山', '原宿'], ['深大寺', '銀座', '新宿', '東京', '鬼太郎茶屋', '台場', '明治神宮'], ['深大寺', '銀座', '台場', '東京', '明治神宮', '原宿'], ['千鳥之淵', '銀座', '井之頭公園', '展望台', '新宿', '東京', '高尾山', '東京鐵塔', '成田機場', '靖國神社', '喜多院', '上野公園'], ['增上寺', '新宿', '長谷寺', '迪士尼樂園', '成田機場', '鎌倉大佛', '上野公園', '雷門', '不忍池', '東照宮', '東京國立博物館', '銀座', '涉谷', '東京', '竹下通', '皇居', '橫濱中華街', '台場', '秋葉原', '橫濱', '新宿御苑', '明治神宮', '東京鐵塔', '富士山', '上野恩賜公園', '東京車站', '六本木', '鶴岡八幡宮', '展望台', '江島神社', '淺草寺', '晴空塔', '原宿', '江之島', '二重橋'], ['深大寺',  ...

# %% [markdown]
#     接著我們要把會用到的點的經緯度座標找出來，然後存進遠端的mariaDB

# %%
from pygeocoder import Geocoder
business_geocoder = Geocoder(api_key='AIzaSyAa0zF1AO-dS7Udipx_zPcbdUJ_LXlBmKc')

# %%
db = pymysql.connect("1.162.48.180","bdse0303","bdse0303","bdse03-travel",charset='utf8' )
cur=db.cursor() 
region="北海道"
for tmp in B:
    for inner in tmp:
        sql='SELECT * FROM ginwaydu WHERE place="'+inner+'"'
        if cur.execute(sql)==0:
            x=geocoder.google(inner).latlng
            if len(x)!=0:
                if x[0]>0 and x[1]>0:
                    sql2 = 'INSERT INTO ginwaydu(place,longtitude,lattitude,region) VALUES ("'+inner+'",'+str(x[0])+','+str(x[1])+',"'+region+'")'
                    cur.execute(sql2)
                else :
                    print("經緯度小於0:"+inner)
            else :
                print("沒有經緯度:"+inner)

    db.commit()
db.close()

# %% [markdown]
#     接著要來計算最短路徑了
#
#     先將一條路線讀出來，做成dictionary，到資料庫幫他找到所有的點的經緯度

# %%
db = pymysql.connect("1.162.48.180","bdse0303","bdse0303","bdse03-travel",charset='utf8' )
cur=db.cursor()

# %%
for content in afterclean: 
    num=1
    ll=[]
    
    for inner in content:
        sql='SELECT * FROM ginwaydu WHERE place="'+inner+'"'
        cur.execute(sql)
        results = cur.fetchall()
        for tmp in results:
            cor=np.array([tmp[1],tmp[2]])
            ll.append(cor)
        num+=num
    db.commit()

    
    
    num=0    
    using={}
    for inner in content:
        using[inner]=ll[num]
        num=num+1

        
        
    pathnum=len(using)                         #6
    finalall=[]                                #最終要的路徑list
    finalshortest=1000000.0                    #最終路徑的長度
    pathuse=[]  
    for i in range(pathnum):                                     #跑六次 每個點當一次起點
    #     print(i)
        startpoint=using[content[i]]                             #這一次起點的座標
        pathlength=0.0                                           #路徑長
    #     print("!!!")
        pathlist=[]
        pathlist.append(startpoint)
        pathuse=[]                                              #路徑要跑的列表
        pathnum=len(using) 
        for il in range(pathnum):                                
            pathuse.append(il)
            #print(pathuse)
    #     print(pathuse)
        pathuse.pop(i)
        #print(pathuse)                                             
        pathnum=len(pathuse) 
    #     print(pathnum)
        for count in range(pathnum):                            #跑五次  共五條直線
            shortest=1000000.0
            now=[]
            tmp=count
    #         print("!!!!!!!")
            for counting in range(pathnum):
                t=pathuse[counting]
                #print(counting)
                #print(shortest)

                ss=using[content[t]]
                #print(ss)
                if math.sqrt(((startpoint - ss)**2)[0]+((startpoint - ss)**2)[1])<shortest:
                    shortest=math.sqrt(((startpoint - ss)**2)[0]+((startpoint - ss)**2)[1])
                    now=ss
                    tmp=counting
                    #print(counting)      
            pathuse.pop(tmp)
            pathnum=pathnum-1
            pathlength=pathlength+shortest
            pathlist.append(now)
    #     print(pathlist)

        if pathlength<finalshortest:
            finalshortest=pathlength
            final=pathlist
    #         print(finalshortest)

    print(final)    
    for a in range(len(final)-1):
        b=a+1
        x=str(final[a][0])
        y=str(final[a][1])
        z=str(final[b][0])
        t=str(final[b][1])

        lp = "INSERT INTO route02(fromx,fromy,tox,toy) VALUES ("+x+","+y+","+z+","+t+")"
        cur.execute(lp)
        
db.commit()
db.close()
# Out:
# [array([  35.6716283,  139.7102847]), array([  35.6763976,  139.6993259]), array([  35.7090259,  139.7319925]), array([  35.6721142,  139.7708253]), array([  35.7147651,  139.7966553]), array([  35.7100627,  139.8107004]), array([  35.6997435,  139.5731906]), array([  35.696238 ,  139.5704317])]
# [array([  35.7110584,  139.7963664]), array([  35.7147651,  139.7966553]), array([  35.7100627,  139.8107004]), array([  35.6654861,  139.7706668]), array([  35.7090259,  139.7319925]), array([  35.6763976,  139.6993259]), array([  35.6997435,  139.5731906]), array([  35.312125,  139.489674]), array([  35.7719867,  140.3928501])]
# [array([  35.6911017,  139.706763 ]), array([  35.729387,  139.718191]), array([  35.3085842,  138.9345062]), array([  35.3605555,  138.7277777])]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-87e4bff3b55d> in <module>()
#      20     using={}
#      21     for inner in content:
# ---> 22         using[inner]=ll[num]
#      23         num=num+1
#      24
#
# IndexError: list index out of range
