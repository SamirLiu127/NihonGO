# %%
import requests #爬伊利電影下載頁 電影名稱,發文日期,瀏覽人數,網址
from bs4 import BeautifulSoup

print('==============page1==============')
res = requests.get('http://www02.eyny.com/forum-205-1.html')
#print(res.text)
soup = BeautifulSoup(res.text,'lxml')
#print(soup.text)
#print(soup.select('.item'))
i=0
for a in soup.select('tbody'):
    #print(a)
    i += 1
    if i>14:
        print(a.select('.xst')[0].text,
              a.select('.by')[0].select('span')[0].text,
              a.select('em')[2].text,)
        print('http://www02.eyny.com/'+a.select('.xst')[0]['href'])
        
print('==============page2==============')
res = requests.get('http://www02.eyny.com/forum-205-3W0P8JX0.html')
#print(res.text)
soup = BeautifulSoup(res.text,'lxml')
#print(soup.text)
#print(soup.select('.item'))
i=0
for a in soup.select('tbody'):
    #print(a)
    i += 1
    if i>14:
        print(a.select('.xst')[0].text,
              a.select('.by')[0].select('span')[0].text,
              a.select('em')[2].text,)
        print('http://www02.eyny.com/'+a.select('.xst')[0]['href'])
# Out:
# ==============page1==============
# [陸] 湄公河行動/湄公河大案 Operation Mekong BDRip-720P+1080P(MKV@950M/1.9G@多免空@簡繁英)(2P) 2016-12-17 12248
# http://www02.eyny.com/thread-11177809-1-3DN3CFFH.html
# [美]西部開拓史 How the West Was Won 1962 弧幕版 1080P BDrip (MKV@4.16GB@MEGA@台版繁中)(7P) 2017-1-16 623
# http://www02.eyny.com/thread-11212112-1-3DN3CFFH.html
# [美]列車上的女孩 2016.WEBRip-720p (MKV@1G@Mega/YU@繁中)(2P) 2017-1-4 22168
# http://www02.eyny.com/thread-11198719-1-3DN3CFFH.html
# [日] 全員單戀 Zenin Kataomoi HDRip-720P(MKV@1.1G@多免空@繁中)(2P) 2017-1-13 2658
# http://www02.eyny.com/thread-11209169-1-3DN3CFFH.html
# [台] 報告班長7：勇往直前 DVD-480p (MP4@2.18GB@MG@繁中)(8P) 2017-1-10 33247
# http://www02.eyny.com/thread-11205731-1-3DN3CFFH.html
# [美] 怒火地平線/ 深海浩劫 Deepwater Horizon BDRip-720P+1080P(MKV@850M/1.6G@多免空@簡繁英)(2P) 2016-12-21 12920
# http://www02.eyny.com/thread-11182658-1-3DN3CFFH.html
# [美]鬼開門 The Disappointments Room WEB-DL 2016 1080p(MKV@2.96GB@MEGA@R3繁中)(4P) 2017-1-16 484
# http://www02.eyny.com/thread-11212036-1-3DN3CFFH.html
# [美] 樂來越愛你/ 星聲夢里人(港) La La Land DVDScr-320P(MKV@850M@多免空@無字)(2P) 2017-1-15 1340
# http://www02.eyny.com/thread-11211882-1-3DN3CFFH.html
# [美]歡迎光臨自殺小鎮.台版DVD原碟字幕(MKV-1080P@6.5GB@MEGA@繁中)(5P) 2017-1-9 4250
# http://www02.eyny.com/thread-11204234-1-3DN3CFFH.html
# [美]薩利機長 哈德遜奇蹟/SULLY/BLURay-1080p(MKV@1.82G@MEGA@正體中文字幕)(8P) 2016-12-4 64234
#print('==============page1==============')
#res = requests.get('http://www02.eyny.com/forum-205-1.html')
chromepath = 'D:\JupyterNotebook\chromedriver.exe'
browser = webdriver.Chrome(chromepath)
browser.get('http://www02.eyny.com/forum-205-1.html')
soup = BeautifulSoup(browser.page_source,'lxml')

print(soup.select('#threadlist form table tbody'))
#count=1
#while count<=3:
#    print('============page'+str(count)+'============')
"""
i=0
for a in soup.select('tbody'):
    i += 1
    if i>14:
        print(a.select('.xst')[0].text,
            a.select('.by')[0].select('span')[0].text,
            a.select('em')[2].text,)
        print('http://www02.eyny.com/'+a.select('.xst')[0]['href'])
        print('============================')
"""
#    browser.find_element_by_link_text(u"下一頁").click()
#    soup = BeautifulSoup(browser.page_source,'lxml')
#    count +=1

browser.close()
# Out:
# [<tbody id="stickthread_224266"><tr onmouseout="document.getElementById('pic_224266').style.display='none'" onmouseover="document.getElementById('pic_224266').style.display='block'"><td class="icn"><a href="thread-224266-1-3DN3CFFH.html" target="_blank" title="全局置頂主題 - 關閉的主題 - 新窗口打開"><img src="static/image/common/folder_lock.gif"/></a></td><td class="p_pre_td"><div style="position:relative"><img alt="尊貴會員計劃 - 無限觀看圖片、附件和下載(5P)" class="p_pre_none" id="pic_224266" src="http://a432.file-static.com/data/attachment/./forum/picture/1101/224266.jpg"/></div><p><img class="p_pre" src="http://a432.file-static.com/data/attachment/./forum/picture/1101/224266.jpg"/></p></td><th class="lock"> <a class="xst" href="forum.php?mod=viewthread&amp;tid=224266&amp;extra=page%3D3DN3CFFH&amp;ad=4" onclick="atarget(this)" style="font-weight: bold;color: #2B65B7">尊貴會員計劃 - 無限觀看圖片、附件和下載(5P)</a><img align="absmiddle" alt="attach_img" src="static/image/filetype/image_s.gif" title="圖片附件"/></th><td class="by"><cite><a c="1" href="space-uid-5.html" mid="GpfDkgYmmmZbXaoJoXYKIYOLWYaWQEZW">天晴</a></cite><em><span>2011-1-1</span></em></td><td class="num"><a class="xi2" href="thread-224266-1-3DN3CFFH.html">0</a><em>65</em></td><td class="by"><cite><a c="1" href="space-username-%E5%A4%A9%E6%99%B4.html" mid="pmamwltrHXVuuTJIqihDpuKtiIbeQOaN">天晴</a></cite><em><a href="forum.php?mod=redirect&amp;tid=224266&amp;goto=lastpost#lastpost">2015-12-21 10:52 PM</a></em></td></tr></tbody>, <tbody id="stickthread_10756045"><tr><td class="icn"><a href="thread-10756045-1-3DN3CFFH.html" target="_blank" title="全局置頂主題 - 關閉的主題 - 新窗口打開"><img src="static/image/common/folder_lock.gif"/></a></td><td class="p_pre_td"> </td><th class="lock"> <a class="xst" href="thread-10756045-1-3DN3CFFH.html" onclick="atarget(this)" style="font-weight: bold;color: #EC1282">重要公告! 嚴禁廣告宣傳! 所有會員必看! 2016/2/24</a></th><td class="by"><cite><a c="1" href="space-uid-2330417.html" mid="FQQLFZTQyegbXaoJoXYKIYOLWYaWQEZW">intela53184</a></cite><em><span>2016-2-2</span></em></td><td class="num"><a class="xi2" href="thread-10756045-1-3DN3CFFH.html">0</a><em>870936</em></td><td class="by"><cite><a c="1" href="space-username-intela53184.html" mid="pmamwleevCceYbwFOjIfkYOLWYaWQOaN">intela53184</a></cite><em><a href="forum.php?mod=redirect&amp;tid=10756045&amp;goto=lastpost#lastpost">2014-10-2 01:48 AM</a></em></td></tr></tbody>, <tbody id="stickthread_262777"><tr><td class="icn"><a href="thread-262777-1-3DN3CFFH.html" target="_blank" title="全局置頂主題 - 關閉的主題 - 新窗口打開"><img src="static/image/common/folder_lock.gif"/></a></td><td class="p_pre_td"> </td><th class="lock"> <a class="xst" href="thread-262777-1-3DN3CFFH.html" onclick="atarget(this)" style="font-weight: bold;color: #2B65B7">伊莉總版規</a><img align="absmiddle" alt="attach_img" src="static/image/filetype/image_s.gif" title="圖片附件"/></th><td class="by"><cite><a c="1" href="space-uid-5.html" mid="GpfDkgYmmmZbXaoJoXYKIYOLWYaWQEZW">天晴</a></cite><em><span>2011-1-1</span></em></td><td class="num"><a class="xi2" href="thread-262777-1-3DN3CFFH.html">0</a><em>1590039</em></td><td class="by"><cite><a c="1" href="space-username-%E5%A4%A9%E6%99%B4.html" mid="pmamwltrHXVuuTJIqihDpuKtiIbeQOaN">天晴</a></cite><em><a href="forum.php?mod=redirect&amp;tid=262777&amp;goto=lastpost#lastpost">2011-1-1 08:00 AM</a></em></td></tr></tbody>, <tbody id="stickthread_11002166"><tr><td class="icn"><a href="thread-11002166-1-3DN3CFFH.html" target="_blank" title="分類置頂主題 - 新窗口打開"><img alt="本區置頂" src="static/image/common/pin_2.gif"/></a></td><td class="p_pre_td"> </td><th class="common"> <a class="xst" href="thread-11002166-1-3DN3CFFH.html" onclick="atarget(this)" style="font-weight: bold;color: #EE5023">【全區適用】複製回文檢舉專區(同時招募助理數名)</a><span class="tps"> ...<a href="thread-11002166-2-3DN3CFFH.html">2</a><a href="thread-11002166-3-3DN3CFFH.html">3</a><a href="thread-11002166-4-3DN3CFFH.html">4</a><a href="thread-11002166-5-3DN3CFFH.html">5</a><a href="thread-11002166-6-3DN3CFFH.html">6</a>..<a href="thread-11002166 ...

# %%
import requests #偽裝header登入
from bs4 import BeautifulSoup

#headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36',
#            "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8"}
url = "https://www.whatismybrowser.com/w/LNNXKFR"
req = requests.get(url)
bsObj = BeautifulSoup(req.text,'lxml')
print(bsObj.select(".user-agent")[0].text)
# Out:
# Their user agent:
#                             Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/55.0.2883.87 Safari/537.36

# %%
from selenium import webdriver #取得cookie
driver = webdriver.PhantomJS(executable_path='<Path to Phantom JS>')
driver.get("http://pythonscraping.com")
driver.implicitly_wait(1)
print(driver.get_cookies())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-1adb0f10d761> in <module>()
# ----> 1 from selenium import webdriver #取得cookie
#       2 driver = webdriver.PhantomJS(executable_path='<Path to Phantom JS>')
#       3 driver.get("http://pythonscraping.com")
#       4 driver.implicitly_wait(1)
#       5 print(driver.get_cookies())
#
# ImportError: No module named 'selenium'
