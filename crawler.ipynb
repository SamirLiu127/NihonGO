# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
import re

# %%
res = requests.get("http://www.backpackers.com.tw/forum/showthread.php?t=1866804")

soup = BeautifulSoup(res.text.encode("utf-8"))

bid_table = soup.findAll('div',{'id':'post_message_9379186'})

print(bid_table)
# Out:
# [<div class="vb_postbit" id="post_message_9379186">
# <!-- http://www.backpackers.com.tw/forum/showthread.php?p=9379186 </div> -->
# <script type="text/javascript">
# <!--
# ysm_type="postbit_guest";
# ysm_postid="9379186";
# //-->
# </script>
# <div id="ysm_postbit_guest_inline">
# </div>
# <a href="http://www.backpackers.com.tw/forum/attachment.php?s=f8a3265422b36762b085bc89b721ac5a&amp;attachmentid=1994843&amp;d=1483792207" id="attachment1994843" rel="Lightbox_9379186" target="_blank"><img alt="按圖片以查看大圖
#
# 名稱:	105.06.03 南一中 (94).jpg
# 查看次數:	5
# 文件大小:	1.84 MB
# ID:	1994843" border="0" class="thumbnail" src="http://sa1.bbkz.net/forum/attachment.php?attachmentid=1994843&amp;thumb=1&amp;d=1483792207" style="margin: 2px"/></a><br/>
# Steven高中畢業去日本玩了一個月，因為旅費有限，所以必須很節儉，<br/>
# 因此我選擇了「Airbnb」「jalan.com」「booking.com」訂房網<br/>
# 如果萬一上面三家訂房網都找不到合適的房間，<br/>
# 那麼我就只好，使出最後大功略了，就是<font color="Blue">「住網咖」</font>啦！<br/>
# <br/>
# 「網咖」就成為我這五天晚上找不到旅館投宿的地方了！<br/>
# ...

# %%
from numpy import pi
print(pi)
# Out:
# 3.141592653589793
